# %%
using Pkg
Pkg.activate("../")
using Plots
# Out:
#  Activating environment at `~/Codes/jl/EasyStream/Project.toml`

# %%
function plotando(x)
    _x = plot(x)
    return _x
end
# Out:
# plotando (generic function with 1 method)

# %%
x = rand(10, 1)
x2 = rand(10, 1)
x3 = rand(10, 1);

# %%
plot1 = plotando(x)
# Out:
# Plot{Plots.GRBackend() n=1}

# %%
plot2 = plotando(x2)
# Out:
# Plot{Plots.GRBackend() n=1}

# %%
plot3 = plotando(x3)
# Out:
# Plot{Plots.GRBackend() n=1}

# %%
plot!(plot3)
# Out:
# Plot{Plots.GRBackend() n=2}
